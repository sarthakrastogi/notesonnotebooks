# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


from google.colab.patches import cv2_imshow

# %% [markdown]
# #?

# %%
myimg = 'stone.jpg'

# %%
image = cv2.imread(myimg)

# %%
image

# %%
image.shape
# Out:
# (901, 593, 3)

# %% [markdown]
# u

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
plt.imshow(image[:, :, 0])
plt.imshow(image[:, :, 1])
plt.imshow(image[:, :, 2])
#plt.imshow(image[:, :, 2], cmap = 'gray')

# %% [markdown]
# #Loading Images

# %% [markdown]
# Loading an image normally

# %%
img = cv2.imread('image.jpg')

# %% [markdown]
# It's easier on the processor to work with black and white image data so

# %%
img = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# Alternatively, the images could be imported as

# %%
img = cv2.imread('image.jpg', cv2.IMREAD_COLOR = 1)
img = cv2.imread('image.jpg', cv2.IMREAD_UNCHANGED = -1)

# %% [markdown]
# Showing images

# %%
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.plot([50, 100], [80, 100], 'c', linewidth = 5)
plt.show()

cv2.imwrite('imageturnedgray.png', img)
# Out:
# True

# %% [markdown]
# #Loading video data

# %% [markdown]
# Recording video and saving it to a file

# %%
cap = cv2.VideoCapture(0) #0 means the first webcam on the system, 1 can mean the second.
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('outputfile.avi', fourcc, 20.0, (640, 480))
while True:
  ret, frame = cap.read()
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
  out.write(frame)
  cv2.imshow('frame', frame)
  cv2.imshow('gray', gray)

  if cv2.waitKey(1) &0xFF == ord('q'):
    break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-ed86f2487738> in <module>()
#       4 while True:
#       5   ret, frame = cap.read()
# ----> 6   gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       7   out.write(frame)
#       8   cv2.imshow('frame', frame)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
