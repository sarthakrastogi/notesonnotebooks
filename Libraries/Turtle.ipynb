# %%
# !pip install mobilechelonian
# Out:
# Collecting mobilechelonian
#   Downloading https://files.pythonhosted.org/packages/2c/89/d79cde973e8b0ab504bbea6d494b7fd7d6e2b4d6a8931b0b19a21368ab9b/mobilechelonian-0.5-py2.py3-none-any.whl (94kB)
# Requirement already satisfied: IPython in c:\users\hp\anaconda3\lib\site-packages (from mobilechelonian) (7.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\hp\anaconda3\lib\site-packages (from mobilechelonian) (7.5.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (2.0.10)
# Requirement already satisfied: traitlets>=4.2 in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (4.3.3)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (0.4.1)
# Requirement already satisfied: pygments in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (2.4.2)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (0.1.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (4.4.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (41.4.0)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from IPython->mobilechelonian) (0.15.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->mobilechelonian) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->mobilechelonian) (5.1.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->mobilechelonian) (4.4.0)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->mobilechelonian) (0.1.7)
# Requirement already satisfied: six>=1.9.0 in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->mobilechelonian) (1.12.0)
# Requirement already satisfied: ipython-genutils in c:\users\hp\anaconda3\lib\site-packages (from traitlets>=4.2->IPython->mobilechelonian) (0.2.0)
# Requirement already satisfied: parso>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.10->IPython->mobilechelonian) (0.5.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\hp\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (6.0.1)
# Requirement already satisfied: jupyter-client in c:\users\hp\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->mobilechelonian) (5.3.3)
# Requirement already satisfied: tornado>=4.2 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->mobilechelonian) (6.0.3)
# Requirement already satisfied: jupyter-core in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->mobilechelonian) (4.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->mobilechelonian) (3.0.2)
# Requirement already satisfied: Send2Trash in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (0.8.2)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (0.7.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (2.10.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (18.1.0)
# Requirement already satisfied: nbconvert in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (5.6.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->mobilechelonian) (223)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->mobilechelonian) (2.8.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->mobilechelonian) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->mobilechelonian) (19.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (1.1.1)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (0.6.0)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (3.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (0.3)
# Requirement already satisfied: testpath in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (0.4.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (1.4.2)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->mobilechelonian) (0.5.1)
# Installing collected packages: mobilechelonian
# Successfully installed mobilechelonian-0.5

# %%
from mobilechelonian import Turtle
t = Turtle()
t.speed(5)
colours=["red","blue","yellow","brown","black","purple","green"]

t.penup(); t.left(90); t.forward(200);t.right(90);t.pendown()
for i in range (0,18):
    t.pencolor(colours[i%7])
    t.right(20)
    t.forward(50)

t.right(180)
t.home()
# Out:
# Turtle()

# %%
t.forward(100)
t.home()

# %%
max_no = int(input())
a = []
cube=lambda x: x*x*x
for i in range(max_no) :
        if i <= 1 :
                a.append(i)
        else:
                f = int(a[i-2])+int(a[i-1])
                a.append(f)
print (list(map(cube,a)))
# Out:
# 5
# [0, 1, 1, 8, 27]
